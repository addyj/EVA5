# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 12.74 MiB | 43.79 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !ls
# Out:
# gdrive	sample_data  YoloV3

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png

# %%
mkdir weights

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png   weights

# %%
# !cp ../gdrive/'My Drive'/yolov3_models/yolov3-spp-ultralytics.pt ./weights

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 10 --cache --epochs 25 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=25, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-24 09:46:15.921909: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 6203.67it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 113.71it/s]
# ...

# %%
# !ls ./data/
# Out:
# coco.names  customdata	samples  smalcoco

# %%
# !mv ./data/customdata ./data/custom_data_old

# %%
# !ls ./data/
# Out:
# coco.names  custom_data_old  samples  smalcoco

# %%
# !unzip ../gdrive/'My Drive'/YoloV3_data/customdata.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: customdata/images/PImage29.jpg
#   inflating: customdata/images/african-american-woman-wearing-hardhat-and-safety-vest-picture-id485445478.jpg
#   inflating: customdata/images/majdoor_95.jpg
#   inflating: customdata/images/construction-worker-working-under-blue-skies.jpg
#   inflating: customdata/images/HV_007.jpg
#   inflating: customdata/images/SImage_44.jpg
#   inflating: customdata/images/E91.jpg
#   inflating: customdata/images/img79.jpg
#   inflating: customdata/images/images41.jpg
#   inflating: customdata/images/SImage_147.jpg
#   inflating: customdata/images/K161.jpg
#   inflating: customdata/images/img60.jpg
#   inflating: customdata/images/R91.jpg
#   inflating: customdata/images/Himage_164.jpg
#   inflating: customdata/images/Kyy.jpg
#   inflating: customdata/images/R47.png
#   inflating: customdata/images/majdoor_66.jpg
#   inflating: customdata/images/Bimg_42.jpg
# ...

# %%
# !ls
# Out:
#  annotation_tool   output	  runs		    'ubdivisions=1'
#  cfg		   __pycache__	  test_batch0.png    utils
#  customdata	   README.md	  test.py	     vim.exe.stackdump
#  data		   results.json   ting		     weights
#  detect.py	   results.png	  train_batch0.png
#  models.py	   results.txt	  train.py

# %%
# !mkdir ./data/customdata

# %%
# !ls ./data
# Out:
# coco.names  customdata	custom_data_old  samples  smalcoco

# %%
# !mv ./customdata/* ./data/customdata

# %%
# !ls ./data/customdata
# Out:
# classes.txt  custom.names  labels	test.txt      train.txt
# custom.data  images	   test.shapes	train.shapes

# %%
# !mv ./cfg/yolov3-custom.cfg ./cfg/yolov3-custom_old.cfg

# %%
# !ls ./cfg
# Out:
# yolov3-custom_old.cfg  yolov3-spp.cfg

# %%
# !cp ../gdrive/'My Drive'/YoloV3_data/yolov3-custom.cfg ./cfg

# %%
# !ls ./cfg
# Out:
# yolov3-custom.cfg  yolov3-custom_old.cfg  yolov3-spp.cfg

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 70
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=70, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-24 10:06:15.053443: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3034 found, 131 missing, 38 empty, 0 duplicate, for 3203 images): 100% 3203/3203 [00:00<00:00, 7779.02it/s]
# Caching images (1.8GB): 100% 3203/3203 [00:21<00:00, 148.68it/s]
# ...

# %%
# !pip install ffmpeg
# Out:
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-cp36-none-any.whl size=6083 sha256=8465f7a18762d9311e0c97e9a40ca3fcf28c635ca1295712f1d9eab5ec1ce238
#   Stored in directory: /root/.cache/pip/wheels/b6/68/c3/a05a35f647ba871e5572b9bbfc0b95fd1c6637a2219f959e7a
# Successfully built ffmpeg
# ...

# %%
import ffmpeg

# %%
# !ls
# Out:
#  annotation_tool   output	  runs		    'ubdivisions=1'
#  cfg		   __pycache__	  test_batch0.png    utils
#  customdata	   README.md	  test.py	     vim.exe.stackdump
#  data		   results.json   ting		     weights
#  detect.py	   results.png	  train_batch0.png
#  models.py	   results.txt	  train.py

# %%
# !mkdir vid_frames

# %%
# !mkdir vid_frames_out

# %%
# !ls
# Out:
#  annotation_tool   output	  runs		    'ubdivisions=1'
#  cfg		   __pycache__	  test_batch0.png    utils
#  customdata	   README.md	  test.py	     vid_frames
#  data		   results.json   ting		     vid_frames_out
#  detect.py	   results.png	  train_batch0.png   vim.exe.stackdump
#  models.py	   results.txt	  train.py	     weights

# %%
# !ffmpeg -i ../yolov3_vid.mp4 ./vid_frames/out-%05d.jpg
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !python detect.py --conf-thres 0.1 --source ./vid_frames --output ./vid_frames_out
# Out:
# Streaming output truncated to the last 5000 lines.
# image 816/5812 vid_frames/out-00816.jpg: 320x512 Done. (0.017s)
# image 817/5812 vid_frames/out-00817.jpg: 320x512 Done. (0.017s)
# image 818/5812 vid_frames/out-00818.jpg: 320x512 Done. (0.018s)
# image 819/5812 vid_frames/out-00819.jpg: 320x512 Done. (0.018s)
# image 820/5812 vid_frames/out-00820.jpg: 320x512 1 bootss, Done. (0.017s)
# image 821/5812 vid_frames/out-00821.jpg: 320x512 1 bootss, Done. (0.017s)
# image 822/5812 vid_frames/out-00822.jpg: 320x512 Done. (0.018s)
# image 823/5812 vid_frames/out-00823.jpg: 320x512 Done. (0.017s)
# image 824/5812 vid_frames/out-00824.jpg: 320x512 Done. (0.017s)
# image 825/5812 vid_frames/out-00825.jpg: 320x512 Done. (0.018s)
# image 826/5812 vid_frames/out-00826.jpg: 320x512 Done. (0.018s)
# image 827/5812 vid_frames/out-00827.jpg: 320x512 Done. (0.017s)
# image 828/5812 vid_frames/out-00828.jpg: 320x512 Done. (0.017s)
# ...

# %%
# !ffmpeg -framerate 24 -i ./vid_frames_out/out-%05d.jpg ../yolov3_vid_out.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %% [markdown]
# #### Redetect on another video

# %%
# !ls
# Out:
#  annotation_tool   output	  runs		    'ubdivisions=1'
#  cfg		   __pycache__	  test_batch0.png    utils
#  customdata	   README.md	  test.py	     vid_frames
#  data		   results.json   ting		     vid_frames_out
#  detect.py	   results.png	  train_batch0.png   vim.exe.stackdump
#  models.py	   results.txt	  train.py	     weights

# %%
# !mkdir vid_frames2
# !mkdir vid_frames_out2

# %%
# !ffmpeg -i ../yolov3_vid2.mp4 ./vid_frames2/out-%05d.jpg
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !python detect.py --conf-thres 0.1 --source ./vid_frames2 --output ./vid_frames_out2
# Out:
# Streaming output truncated to the last 5000 lines.
# image 1984/6980 vid_frames2/out-01984.jpg: 320x512 2 hardhats, Done. (0.017s)
# image 1985/6980 vid_frames2/out-01985.jpg: 320x512 1 hardhats, Done. (0.018s)
# image 1986/6980 vid_frames2/out-01986.jpg: 320x512 1 hardhats, Done. (0.017s)
# image 1987/6980 vid_frames2/out-01987.jpg: 320x512 1 hardhats, Done. (0.017s)
# image 1988/6980 vid_frames2/out-01988.jpg: 320x512 1 hardhats, Done. (0.018s)
# image 1989/6980 vid_frames2/out-01989.jpg: 320x512 1 hardhats, Done. (0.017s)
# image 1990/6980 vid_frames2/out-01990.jpg: 320x512 1 hardhats, Done. (0.019s)
# image 1991/6980 vid_frames2/out-01991.jpg: 320x512 1 hardhats, Done. (0.017s)
# image 1992/6980 vid_frames2/out-01992.jpg: 320x512 1 hardhats, Done. (0.017s)
# image 1993/6980 vid_frames2/out-01993.jpg: 320x512 1 hardhats, Done. (0.018s)
# image 1994/6980 vid_frames2/out-01994.jpg: 320x512 1 hardhats, Done. (0.017s)
# ...

# %%
# !ffmpeg -framerate 24 -i ./vid_frames_out2/out-%05d.jpg ../yolov3_vid_out2.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !cp -r ./weights/* ../gdrive/'My Drive'/YoloV3_data/

# %%
# !cp ../yolov3_vid_out2.mp4 ../gdrive/'My Drive'/YoloV3_data/

# %%
# !cp ../yolov3_vid_out.mp4 ../gdrive/'My Drive'/YoloV3_data/
